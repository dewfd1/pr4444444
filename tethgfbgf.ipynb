# %% [markdown]
# Цель: Необходимо использовать датасет с прошлой практической работы и визуализировать данные в виде графиков: Линейный график - минимум 3 штуки (можно использовать наложение графиков), Столбчатая диаграмма- минимум 3 штуки (можно также использовать наложение), Круговая диаграмма - минимум 2 штуки, Диаграмма рассеяния - минимум 2 штуки, Гистограмма - минимум 3 штукиЦель: Необходимо использовать датасет с прошлой практической работы и визуализировать данные в виде графиков: Линейный график - минимум 3 штуки (можно использовать наложение графиков), Столбчатая диаграмма- минимум 3 штуки (можно также использовать наложение), Круговая диаграмма - минимум 2 штуки, Диаграмма рассеяния - минимум 2 штуки, Гистограмма - минимум 3 штуки

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Импортируем нужные библиотеки. Рandas предоставляет инструменты для обработки и анализа структурированных данных. Библиотека pandas также предоставляет функциональность для чтения и записи данных из различных источников, включая CSV. Библиотека matplotlib.pyplot, предоставляет функции для создания различных видов графиков и диаграмм: линейные графики, столбчатые диаграммы, круговые диаграммы, диаграммы рассеяния, гистограммы.

# %%
data = pd.read_csv('roblox_account_index.csv')

# %% [markdown]
# Загрузка данных из CSV-файла

# %%
plt.figure(figsize=(10, 5))
plt.subplot(231)
plt.plot(data['user_id'], data['username'])
plt.title('Линейный график 1')
plt.subplot(232)
plt.plot(data['avatar'], data['avatar_headshot'])
plt.title('Линейный график 2')
plt.subplot(233)
plt.plot(data['username'], data['display_name'])
plt.title('Линейный график 3')
# Out:
# Text(0.5, 1.0, 'Линейный график 3')
# C:\Users\1\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 25105 (\N{CJK UNIFIED IDEOGRAPH-6211}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\1\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 24178 (\N{CJK UNIFIED IDEOGRAPH-5E72}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\1\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 27963 (\N{CJK UNIFIED IDEOGRAPH-6D3B}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\1\PycharmProjects\pythonProject3\venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 39532 (\N{CJK UNIFIED IDEOGRAPH-9A6C}) missing from current font.
#   func(*args, **kwargs)
# ...
